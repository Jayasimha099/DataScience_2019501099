# %% [markdown]
# # 2.	If we define daily gain or loss of a stock is the % of change of the stock closing price to previous day closing price. Compute daily gain or loss for each S&P500 company. Do the same thing for weekly and monthly gains or losses.

# %%
#importing required necessary libraries to perform analysis.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations

# %%
#improting necessary libraries to scrape the data.
#using pool method to multiprocessing for download faster.
import requests
import urllib
from bs4 import BeautifulSoup
import re
import io
import gzip
import time
import csv
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from multiprocessing import Pool
import import_ipynb
import pandas as pd
from ipynb.fs.full.scraping_daily_data import scraping_daily_data

driver = webdriver.Chrome(ChromeDriverManager().install())
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
driver.get(url)

symbols = list()
symbols_GICC = dict()

table = "/html/body/div[3]/div[3]/div[5]/div[1]/table[1]"
table = driver.find_element_by_xpath(table)
elements = table.find_elements_by_tag_name("tr")[1:]

for row in elements:
    data = [data.text for data in row.find_elements_by_tag_name("td")]
    #here i am storung all the data related to a date in a dictioanry.
    symbols.append(data[0])
    symbols_GICC[data[0]] = data[3]

print(len(symbols_GICC))
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\Jayasimha\.wdm\drivers\chromedriver\win32\91.0.4472.19\chromedriver.exe] found in cache
# 505

# %%
#here computing daily gain or loss for each company for daily stocks, weekly an dmonthly
gain_loss_daily = pd.DataFrame(columns=["symbol","gain_loss","GICS"])
gain_loss_weekly = pd.DataFrame(columns=["symbol","gain_loss","GICS"])
gain_loss_monthly = pd.DataFrame(columns=["symbol","gain_loss","GICS"])

# %%
daily_dfs = {}
weekly_dfs = {}
monthly_dfs = {}


def gain_loss(sym):
    #DAILY
    #reading the csv file every file ends with daily for daily stock.
    df_daily = pd.read_csv(sym +"_daily" + ".csv")
    #here as told in question, applying formula. previous day-present closing price/present clsoing price.
    #here shit(1) means it takes the previous available value in dataframe.
    df_daily["Gain/Loss"] = (df_daily["Close"] - df_daily["Close"].shift(1)) / df_daily["Close"]
    
    #here daily gain/loss is gievn for every ticker symbol.
    daily_dfs[sym] = df_daily
    
    #WEEKLY
    df_weekly = pd.read_csv(sym +"_weekly"+".csv")
    df_weekly["Gain/Loss"] = (df_weekly["Close"] - df_weekly["Close"].shift(1)) / df_weekly["Close"]
    weekly_dfs[sym] = df_weekly
    
    #MONTHLY
    df_monthly = pd.read_csv(sym + "_monthly" + ".csv")
    df_monthly["Gain/Loss"] = (df_monthly["Close"] - df_monthly["Close"].shift(1)) / df_weekly["Close"]
    monthly_dfs[sym] = df_monthly
    
    #Here creating a dictionary to store all the gain/loss for all symbols by calling the gain_loss method.
    daily = {"symbol":sym,"gain_loss":df_daily["Gain/Loss"].sum(),"GICS":symbols_GICC[sym]}
    weekly = {"symbol":sym,"gain_loss":df_weekly["Gain/Loss"].sum(),"GICS":symbols_GICC[sym]}
    monthly = {"symbol":sym,"gain_loss":df_monthly["Gain/Loss"].sum(),"GICS":symbols_GICC[sym]}
    
    return (daily,weekly,monthly)

# %%
for n in symbols:
    try:
        (daily,weekly,monthly) = gain_loss(n)
        #now inserting all the method call values in dataframes created earlier.
        gain_loss_daily = gain_loss_daily.append(daily, ignore_index=True)
        #here for each df, creating an index and 3 columsn.
        gain_loss_weekly = gain_loss_weekly.append(weekly, ignore_index=True)
        gain_loss_monthly = gain_loss_monthly.append(monthly, ignore_index=True)
    except Exception as e:
        pass

# %%
print(gain_loss_daily)
print(gain_loss_weekly)
print(gain_loss_monthly)
# Out:
#     symbol  gain_loss                    GICS
# 0      MMM   0.022650             Industrials
# 1      ABT   0.775921             Health Care
# 2     ABBV   0.402984             Health Care
# 3     ABMD   0.868232             Health Care
# 4      ACN   0.782966  Information Technology
# ..     ...        ...                     ...
# 240    MKC   0.673513        Consumer Staples
# 241    MDT   0.285405             Health Care
# 242   MCHP   0.731854  Information Technology
# 243    TAP  -0.941475        Consumer Staples
# 244     MS   0.475200              Financials
#
# [245 rows x 3 columns]
#     symbol  gain_loss                    GICS
# 0      MMM   0.076890             Industrials
# 1      ABT   0.847760             Health Care
# 2     ABBV   0.435138             Health Care
# 3     ABMD   0.891735             Health Care
# 4      ACN   0.828857  Information Technology
# ..     ...        ...                     ...
# 240    MKC   0.708544        Consumer Staples
# 241    MDT   0.316487             Health Care
# 242   MCHP   0.802615  Information Technology
# 243    TAP  -0.957985        Consumer Staples
# 244     MS   0.561547              Financials
#
# [245 rows x 3 columns]
#     symbol  gain_loss                    GICS
# 0      MMM   0.180066             Industrials
# 1      ABT   2.063769             Health Care
# 2     ABBV   0.796004             Health Care
# 3     ABMD   2.500622             Health Care
# 4      ACN   1.193002  Information Technology
# ..     ...        ...                     ...
# 240    MKC   0.962392        Consumer Staples
# 241    MDT   0.430314             Health Care
# 242   MCHP   1.637921  Information Technology
# 243    TAP  -0.376565        Consumer Staples
# 244     MS   1.253259              Financials
#
# [245 rows x 3 columns]

# %% [markdown]
# # 3.	Top 25 gainers of S&P 500 for 1000 trading days are the companies which have max % gain during those 1000 trading days. Bottom 25 gainers of S&P 500 for 1000 trading days are the companies which have least % gain (it can be negative gain too which is loss) during those 1000 trading days. Compute and draw the correlation matrix for the top 25 and bottom 25 companies for daily gains or losses. This is a matrix with both axes holding the stock names. The color of each cell is the correlation between that pair of stocks: red for -1 and blue for 1. Do the same thing for weekly and monthly gains or losses.

# %%
#sorting the values as it asked for top values only.
gain_loss_daily = gain_loss_daily.sort_values(by=["gain_loss"])

#this gives us the top 25 gain values
gain_25_daily = gain_loss_daily.head(25)

#this gives bottom loss values
loss_25_daily = gain_loss_daily.tail(25)

#here ticker symbols are company names
gain_25_daily_names = list(gain_25_daily["symbol"])
loss_25_daily_names = list(loss_25_daily["symbol"])

#now for correlation matrix we need to find the combined relation by combining gain and loss names.
names = set(loss_25_daily_names+gain_25_daily_names)
samp = pd.DataFrame(columns=names,index=names)

for n1,n2 in combinations(names,2):
    df1 = daily_dfs[n1]
    df2 = daily_dfs[n2]
    samp.loc[n1,n2] = df1["Gain/Loss"].corr(df2["Gain/Loss"])
    samp.loc[n2,n1] = df2["Gain/Loss"].corr(df1["Gain/Loss"])
    samp.loc[n1,n1] = 1
    samp.loc[n2,n2] = 1
daily_samp = samp.astype({name:"float" for name in names})
daily_samp.style.background_gradient(cmap="brg")
# Out:
# <style  type="text/css" >
# #T_bd22d_row0_col0,#T_bd22d_row1_col1,#T_bd22d_row2_col2,#T_bd22d_row3_col3,#T_bd22d_row4_col4,#T_bd22d_row5_col5,#T_bd22d_row6_col6,#T_bd22d_row7_col7,#T_bd22d_row8_col8,#T_bd22d_row9_col9,#T_bd22d_row10_col10,#T_bd22d_row11_col11,#T_bd22d_row12_col12,#T_bd22d_row13_col13,#T_bd22d_row14_col14,#T_bd22d_row15_col15,#T_bd22d_row16_col16,#T_bd22d_row17_col17,#T_bd22d_row18_col18,#T_bd22d_row19_col19,#T_bd22d_row20_col20,#T_bd22d_row21_col21,#T_bd22d_row22_col22,#T_bd22d_row23_col23,#T_bd22d_row24_col24,#T_bd22d_row25_col25,#T_bd22d_row26_col26,#T_bd22d_row27_col27,#T_bd22d_row28_col28,#T_bd22d_row29_col29,#T_bd22d_row30_col30,#T_bd22d_row31_col31,#T_bd22d_row32_col32,#T_bd22d_row33_col33,#T_bd22d_row34_col34,#T_bd22d_row35_col35,#T_bd22d_row36_col36,#T_bd22d_row37_col37,#T_bd22d_row38_col38,#T_bd22d_row39_col39,#T_bd22d_row40_col40,#T_bd22d_row41_col41,#T_bd22d_row42_col42,#T_bd22d_row43_col43,#T_bd22d_row44_col44,#T_bd22d_row45_col45,#T_bd22d_row46_col46,#T_bd22d_row47_col47,#T_bd22d_row48_col48,#T_bd22d_row49_col49{
#             background-color:  #00ff00;
#             color:  #000000;
#         }#T_bd22d_row0_col1,#T_bd22d_row0_col21,#T_bd22d_row0_col31,#T_bd22d_row0_col40,#T_bd22d_row13_col43,#T_bd22d_row14_col1,#T_bd22d_row16_col1,#T_bd22d_row16_col32,#T_bd22d_row18_col2,#T_bd22d_row19_col13,#T_bd22d_row21_col12,#T_bd22d_row26_col47,#T_bd22d_row28_col0,#T_bd22d_row29_col33,#T_bd22d_row33_col1,#T_bd22d_row33_col4,#T_bd22d_row36_col48,#T_bd22d_row41_col30,#T_bd22d_row41_col34,#T_bd22d_row44_col21,#T_bd22d_row44_col41,#T_bd22d_row48_col38{
#             background-color:  #3800c7;
#             color:  #f1f1f1;
#         }#T_bd22d_row0_col2,#T_bd22d_row0_col7,#T_bd22d_row0_col14,#T_bd22d_row0_col35,#T_bd22d_row2_col25,#T_bd22d_row5_col29,#T_bd22d_row6_col47,#T_bd22d_row9_col10,#T_bd22d_row11_col45,#T_bd22d_row14_col22,#T_bd22d_row21_col10,#T_bd22d_row29_col0,#T_bd22d_row37_col18,#T_bd22d_row42_col29,#T_bd22d_row43_col10,#T_bd22d_row43_col34,#T_bd22d_row45_col29,#T_bd22d_row47_col12,#T_bd22d_row48_col36{
#             background-color:  #3e00c1;
#             color:  #f1f1f1;
#         }#T_bd22d_row0_col3,#T_bd22d_row1_col0,#T_bd22d_row2_col39,#T_bd22d_row4_col23,#T_bd22d_row6_col4,#T_bd22d_row6_col22,#T_bd22d_row8_col48,#T_bd22d_row9_col45,#T_bd22d_row10_col21,#T_bd22d_row10_col36,#T_bd22d_row11_col0,#T_bd22d_row11_col40,#T_bd22d_row19_col30,#T_bd22d_row23_col7,#T_bd22d_row24_col20,#T_bd22d_row27_col17,#T_bd22d_row29_col23,#T_bd22d_row29_col47,#T_bd22d_row31_col8,#T_bd22d_row33_col31,#T_bd22d_row44_col1,#T_bd22d_row44_col20,#T_bd22d_row44_col29,#T_bd22d_row45_col38{
#             background-color:  #6e0091;
#             color:  #f1f1f1;
#         }#T_bd22d_row0_col4,#T_bd22d_row3_col42,#T_bd22d_row4_col7,#T_bd22d_row5_col9,#T_bd22d_row5_col23,#T_bd22d_row7_col25,#T_bd22d_row7_col30,#T_bd22d_row13_col37,#T_bd22d_row15_col16,#T_bd22d_row16_col33,#T_bd22d_row17_col48,#T_bd22d_row22_col49,#T_bd22d_row25_col40,#T_bd22d_row29_col44,#T_bd22d_row31_col7,#T_bd22d_row33_col38,#T_bd22d_row33_col42,#T_bd22d_row34_col45,#T_bd22d_row38_col20,#T_bd22d_row43_col26,#T_bd22d_row44_col34,#T_bd22d_row46_col8{
#             background-color:  #8c0073;
#             color:  #f1f1f1;
#         }#T_bd22d_row0_col5,#T_bd22d_row2_col47,#T_bd22d_row13_col49,#T_bd22d_row14_col40,#T_bd22d_row17_col0,#T_bd22d_row17_col4,#T_bd22d_row17_col39,#T_bd22d_row24_col12,#T_bd22d_row26_col14,#T_bd22d_row31_col29,#T_bd22d_row41_col29,#T_bd22d_row42_col47,#T_bd22d_row47_col27{
#             background-color:  #1a00e5;
#             color:  #f1f1f1;
#         }#T_bd22d_row0_col6,#T_bd22d_row0_col8,#T_bd22d_row2_col6,#T_bd22d_row6_col13,#T_bd22d_row9_col48,#T_bd22d_row16_col30,#T_bd22d_row23_col13,#T_bd22d_row29_col2,#T_bd22d_row29_col26,#T_bd22d_row36_col10,#T_bd22d_row39_col34,#T_bd22d_row40_col13,#T_bd22d_row42_col14,#T_bd22d_row43_col37,#T_bd22d_row45_col12,#T_bd22d_row48_col5{
#             background-color:  #2a00d5;
#             color:  #f1f1f1;
#         }#T_bd22d_row0_col9,#T_bd22d_row6_col37,#T_bd22d_row8_col13,#T_bd22d_row9_col2,#T_bd22d_row9_col11,#T_bd22d_row10_col26,#T_bd22d_row10_col33,#T_bd22d_row11_col5,#T_bd22d_row12_col8,#T_bd22d_row14_col3,#T_bd22d_row14_col29,#T_bd22d_row17_col10,#T_bd22d_row19_col14,#T_bd22d_row21_col48,#T_bd22d_row24_col32,#T_bd22d_row28_col1,#T_bd22d_row29_col1,#T_bd22d_row29_col7,#T_bd22d_row34_col36,#T_bd22d_row35_col10,#T_bd22d_row38_col0,#T_bd22d_row38_col2,#T_bd22d_row38_col47,#T_bd22d_row39_col0,#T_bd22d_row39_col1,#T_bd22d_row39_col11,#T_bd22d_row44_col2,#T_bd22d_row44_col7,#T_bd22d_row44_col8,#T_bd22d_row45_col44,#T_bd22d_row47_col17,#T_bd22d_row49_col25{
#             background-color:  #4e00b1;
#             color:  #f1f1f1;
#         }#T_bd22d_row0_col10,#T_bd22d_row1_col11,#T_bd22d_row1_col18,#T_bd22d_row3_col35,#T_bd22d_row9_col15,#T_bd22d_row10_col14,#T_bd22d_row10_col47,#T_bd22d_row11_col30,#T_bd22d_row16_col5,#T_bd22d_row18_col16,#T_bd22d_row18_col36,#T_bd22d_row20_col21,#T_bd22d_row20_col44,#T_bd22d_row21_col5,#T_bd22d_row21_col8,#T_bd22d_row22_col29,#T_bd22d_row22_col38,#T_bd22d_row25_col8,#T_bd22d_row25_col24,#T_bd22d_row27_col14,#T_bd22d_row28_col26,#T_bd22d_row30_col13,#T_bd22d_row30_col19,#T_bd22d_row30_col39,#T_bd22d_row34_col12,#T_bd22d_row34_col13,#T_bd22d_row35_col32,#T_bd22d_row42_col26{
#             background-color:  #92006d;
#             color:  #f1f1f1;
#         }#T_bd22d_row0_col11,#T_bd22d_row2_col40,#T_bd22d_row9_col0,#T_bd22d_row12_col18,#T_bd22d_row14_col45,#T_bd22d_row16_col48,#T_bd22d_row18_col15,#T_bd22d_row18_col17,#T_bd22d_row26_col1,#T_bd22d_row29_col38,#T_bd22d_row29_col41,#T_bd22d_row33_col14,#T_bd22d_row33_col44,#T_bd22d_row34_col2,#T_bd22d_row35_col0,#T_bd22d_row35_col29,#T_bd22d_row37_col38,#T_bd22d_row39_col17,#T_bd22d_row39_col46,#T_bd22d_row42_col17,#T_bd22d_row43_col22,#T_bd22d_row45_col10,#T_bd22d_row48_col16,#T_bd22d_row48_col21{
#             background-color:  #4400bb;
#             color:  #f1f1f1;
#         }#T_bd22d_row0_col12,#T_bd22d_row0_col25,#T_bd22d_row1_col14,#T_bd22d_row1_col16,#T_bd22d_row3_col21,#T_bd22d_row3_col39,#T_bd22d_row3_col45,#T_bd22d_row4_col9,#T_bd22d_row5_col18,#T_bd22d_row5_col41,#T_bd22d_row5_col45,#T_bd22d_row7_col33,#T_bd22d_row8_col45,#T_bd22d_row10_col39,#T_bd22d_row19_col11,#T_bd22d_row19_col25,#T_bd22d_row20_col6,#T_bd22d_row21_col33,#T_bd22d_row22_col41,#T_bd22d_row28_col25,#T_bd22d_row32_col17,#T_bd22d_row32_col29,#T_bd22d_row37_col0,#T_bd22d_row48_col11{
#             background-color:  #7e0081;
#             color:  #f1f1f1;
#         }#T_bd22d_row0_col13,#T_bd22d_row0_col28,#T_bd22d_row1_col45,#T_bd22d_row6_col44,#T_bd22d_row10_col31,#T_bd22d_row18_col1,#T_bd22d_row19_col2,#T_bd22d_row21_col32,#T_bd22d_row22_col18,#T_bd22d_row26_col27,#T_bd22d_row29_col5,#T_bd22d_row29_col35,#T_bd22d_row29_col46,#T_bd22d_row30_col18,#T_bd22d_row33_col6,#T_bd22d_row33_col15,#T_bd22d_row35_col44,#T_bd22d_row36_col2,#T_bd22d_row38_col37,#T_bd22d_row40_col2,#T_bd22d_row42_col4,#T_bd22d_row42_col10,#T_bd22d_row42_col44,#T_bd22d_row44_col39,#T_bd22d_row48_col42,#T_bd22d_row48_col47,#T_bd22d_row49_col46{
#             background-color:  #5600a9;
#             color:  #f1f1f1;
#         }#T_bd22d_row0_col15,#T_bd22d_row6_col31,#T_bd22d_row7_col26,#T_bd22d_row10_col29,#T_bd22d_row12_col32,#T_bd22d_row13_col10,#T_bd22d_row15_col8,#T_bd22d_row15_col36,#T_bd22d_row20_col31,#T_bd22d_row20_col42,#T_bd22d_row21_col26,#T_bd22d_row22_col19,#T_bd22d_row28_col8,#T_bd22d_row32_col23,#T_bd22d_row32_col41,#T_bd22d_row33_col21,#T_bd22d_row39_col18,#T_bd22d_row46_col0,#T_bd22d_row49_col31{
#             background-color:  #94006b;
#             color:  #f1f1f1;
#         }#T_bd22d_row0_col16,#T_bd22d_row2_col0,#T_bd22d_row2_col17,#T_bd22d_row5_col15,#T_bd22d_row13_col39,#T_bd22d_row14_col19,#T_bd22d_row14_col25,#T_bd22d_row16_col46,#T_bd22d_row17_col29,#T_bd22d_row21_col0,#T_bd22d_row21_col2,#T_bd22d_row21_col4,#T_bd22d_row23_col22,#T_bd22d_row26_col30,#T_bd22d_row28_col4,#T_bd22d_row28_col29,#T_bd22d_row31_col30,#T_bd22d_row31_col44,#T_bd22d_ro

# %% [markdown]
# #Correlation matrix for Weekly data

# %%
gain_loss_weekly = gain_loss_weekly.sort_values(by=["gain_loss"])
gain_25_daily = gain_loss_weekly.head(25)
loss_25_daily = gain_loss_weekly.tail(25)

gain_25_daily_names = list(gain_25_daily["symbol"])
loss_25_daily_names = list(loss_25_daily["symbol"])
names = set(loss_25_daily_names+gain_25_daily_names)
samp = pd.DataFrame(columns=names,index=names)
for n1,n2 in combinations(names,2):
    df1 = daily_dfs[n1]
    df2 = daily_dfs[n2]
    samp.loc[n1,n2] = df1["Gain/Loss"].corr(df2["Gain/Loss"])
    samp.loc[n2,n1] = df2["Gain/Loss"].corr(df1["Gain/Loss"])
    samp.loc[n1,n1] = 1
    samp.loc[n2,n2] = 1
weekly_samp = samp.astype({name:"float" for name in names})
weekly_samp.style.background_gradient(cmap="brg")
# Out:
# <style  type="text/css" >
# #T_63fa1_row0_col0,#T_63fa1_row1_col1,#T_63fa1_row2_col2,#T_63fa1_row3_col3,#T_63fa1_row4_col4,#T_63fa1_row5_col5,#T_63fa1_row6_col6,#T_63fa1_row7_col7,#T_63fa1_row8_col8,#T_63fa1_row9_col9,#T_63fa1_row10_col10,#T_63fa1_row11_col11,#T_63fa1_row12_col12,#T_63fa1_row13_col13,#T_63fa1_row14_col14,#T_63fa1_row15_col15,#T_63fa1_row16_col16,#T_63fa1_row17_col17,#T_63fa1_row18_col18,#T_63fa1_row19_col19,#T_63fa1_row20_col20,#T_63fa1_row21_col21,#T_63fa1_row22_col22,#T_63fa1_row23_col23,#T_63fa1_row24_col24,#T_63fa1_row25_col25,#T_63fa1_row26_col26,#T_63fa1_row27_col27,#T_63fa1_row28_col28,#T_63fa1_row29_col29,#T_63fa1_row30_col30,#T_63fa1_row31_col31,#T_63fa1_row32_col32,#T_63fa1_row33_col33,#T_63fa1_row34_col34,#T_63fa1_row35_col35,#T_63fa1_row36_col36,#T_63fa1_row37_col37,#T_63fa1_row38_col38,#T_63fa1_row39_col39,#T_63fa1_row40_col40,#T_63fa1_row41_col41,#T_63fa1_row42_col42,#T_63fa1_row43_col43,#T_63fa1_row44_col44,#T_63fa1_row45_col45,#T_63fa1_row46_col46,#T_63fa1_row47_col47,#T_63fa1_row48_col48,#T_63fa1_row49_col49{
#             background-color:  #00ff00;
#             color:  #000000;
#         }#T_63fa1_row0_col1,#T_63fa1_row2_col6,#T_63fa1_row6_col12,#T_63fa1_row8_col48,#T_63fa1_row14_col1,#T_63fa1_row15_col1,#T_63fa1_row21_col12,#T_63fa1_row27_col29,#T_63fa1_row28_col2,#T_63fa1_row28_col24,#T_63fa1_row32_col1,#T_63fa1_row32_col13,#T_63fa1_row32_col25,#T_63fa1_row35_col9,#T_63fa1_row36_col21,#T_63fa1_row39_col26,#T_63fa1_row39_col33,#T_63fa1_row40_col12,#T_63fa1_row42_col14,#T_63fa1_row43_col36,#T_63fa1_row45_col11{
#             background-color:  #2a00d5;
#             color:  #f1f1f1;
#         }#T_63fa1_row0_col2,#T_63fa1_row0_col14,#T_63fa1_row5_col28,#T_63fa1_row8_col9,#T_63fa1_row8_col29,#T_63fa1_row9_col41,#T_63fa1_row10_col45,#T_63fa1_row12_col46,#T_63fa1_row14_col20,#T_63fa1_row19_col9,#T_63fa1_row19_col23,#T_63fa1_row19_col26,#T_63fa1_row19_col31,#T_63fa1_row28_col0,#T_63fa1_row28_col31,#T_63fa1_row32_col29,#T_63fa1_row36_col16,#T_63fa1_row36_col19,#T_63fa1_row36_col43,#T_63fa1_row42_col28,#T_63fa1_row43_col9,#T_63fa1_row43_col33,#T_63fa1_row45_col28,#T_63fa1_row47_col2,#T_63fa1_row47_col12,#T_63fa1_row47_col36,#T_63fa1_row49_col23{
#             background-color:  #3e00c1;
#             color:  #f1f1f1;
#         }#T_63fa1_row0_col3,#T_63fa1_row0_col13,#T_63fa1_row1_col0,#T_63fa1_row4_col19,#T_63fa1_row6_col4,#T_63fa1_row6_col20,#T_63fa1_row7_col48,#T_63fa1_row8_col21,#T_63fa1_row8_col45,#T_63fa1_row9_col7,#T_63fa1_row10_col0,#T_63fa1_row10_col7,#T_63fa1_row13_col32,#T_63fa1_row20_col47,#T_63fa1_row23_col15,#T_63fa1_row23_col35,#T_63fa1_row24_col35,#T_63fa1_row25_col5,#T_63fa1_row26_col41,#T_63fa1_row29_col27,#T_63fa1_row29_col40,#T_63fa1_row32_col30,#T_63fa1_row32_col38,#T_63fa1_row33_col6,#T_63fa1_row33_col27,#T_63fa1_row34_col29,#T_63fa1_row40_col18,#T_63fa1_row44_col28,#T_63fa1_row47_col33{
#             background-color:  #6e0091;
#             color:  #f1f1f1;
#         }#T_63fa1_row0_col4,#T_63fa1_row1_col31,#T_63fa1_row3_col34,#T_63fa1_row4_col6,#T_63fa1_row10_col42,#T_63fa1_row12_col36,#T_63fa1_row16_col42,#T_63fa1_row18_col17,#T_63fa1_row20_col49,#T_63fa1_row22_col7,#T_63fa1_row23_col34,#T_63fa1_row23_col39,#T_63fa1_row26_col19,#T_63fa1_row28_col44,#T_63fa1_row32_col17,#T_63fa1_row33_col45,#T_63fa1_row37_col29,#T_63fa1_row38_col44,#T_63fa1_row38_col48,#T_63fa1_row42_col25,#T_63fa1_row43_col24,#T_63fa1_row44_col33,#T_63fa1_row47_col26,#T_63fa1_row49_col8,#T_63fa1_row49_col43{
#             background-color:  #8c0073;
#             color:  #f1f1f1;
#         }#T_63fa1_row0_col5,#T_63fa1_row2_col13,#T_63fa1_row12_col19,#T_63fa1_row12_col40,#T_63fa1_row12_col41,#T_63fa1_row45_col25,#T_63fa1_row45_col29,#T_63fa1_row48_col8{
#             background-color:  #0400fb;
#             color:  #f1f1f1;
#         }#T_63fa1_row0_col6,#T_63fa1_row2_col41,#T_63fa1_row5_col11,#T_63fa1_row5_col29,#T_63fa1_row11_col5,#T_63fa1_row12_col30,#T_63fa1_row14_col2,#T_63fa1_row15_col26,#T_63fa1_row15_col46,#T_63fa1_row18_col5,#T_63fa1_row24_col9,#T_63fa1_row24_col10,#T_63fa1_row24_col33,#T_63fa1_row27_col48,#T_63fa1_row28_col47,#T_63fa1_row34_col14,#T_63fa1_row35_col18,#T_63fa1_row35_col46,#T_63fa1_row36_col27,#T_63fa1_row39_col12,#T_63fa1_row41_col29,#T_63fa1_row44_col21,#T_63fa1_row44_col47{
#             background-color:  #2800d7;
#             color:  #f1f1f1;
#         }#T_63fa1_row0_col7,#T_63fa1_row5_col0,#T_63fa1_row5_col23,#T_63fa1_row5_col25,#T_63fa1_row15_col3,#T_63fa1_row15_col9,#T_63fa1_row15_col23,#T_63fa1_row15_col36,#T_63fa1_row16_col26,#T_63fa1_row16_col33,#T_63fa1_row30_col10,#T_63fa1_row30_col12,#T_63fa1_row39_col36,#T_63fa1_row41_col4,#T_63fa1_row43_col14,#T_63fa1_row44_col8,#T_63fa1_row44_col32,#T_63fa1_row45_col13{
#             background-color:  #1c00e3;
#             color:  #f1f1f1;
#         }#T_63fa1_row0_col8,#T_63fa1_row0_col45,#T_63fa1_row2_col9,#T_63fa1_row5_col1,#T_63fa1_row11_col15,#T_63fa1_row14_col46,#T_63fa1_row15_col28,#T_63fa1_row21_col46,#T_63fa1_row28_col16,#T_63fa1_row32_col18,#T_63fa1_row32_col23,#T_63fa1_row32_col26,#T_63fa1_row32_col28,#T_63fa1_row32_col31,#T_63fa1_row36_col42,#T_63fa1_row41_col18,#T_63fa1_row41_col26,#T_63fa1_row41_col46,#T_63fa1_row43_col28,#T_63fa1_row43_col48,#T_63fa1_row44_col27,#T_63fa1_row48_col6{
#             background-color:  #3200cd;
#             color:  #f1f1f1;
#         }#T_63fa1_row0_col9,#T_63fa1_row1_col10,#T_63fa1_row1_col16,#T_63fa1_row5_col40,#T_63fa1_row9_col14,#T_63fa1_row15_col37,#T_63fa1_row18_col44,#T_63fa1_row20_col28,#T_63fa1_row25_col14,#T_63fa1_row26_col45,#T_63fa1_row27_col24,#T_63fa1_row27_col25,#T_63fa1_row29_col12,#T_63fa1_row29_col47,#T_63fa1_row30_col39,#T_63fa1_row32_col19,#T_63fa1_row33_col11,#T_63fa1_row33_col12,#T_63fa1_row34_col32,#T_63fa1_row38_col46,#T_63fa1_row42_col24,#T_63fa1_row44_col26,#T_63fa1_row47_col25{
#             background-color:  #92006d;
#             color:  #f1f1f1;
#         }#T_63fa1_row0_col10,#T_63fa1_row0_col25,#T_63fa1_row2_col21,#T_63fa1_row8_col0,#T_63fa1_row11_col16,#T_63fa1_row14_col45,#T_63fa1_row15_col48,#T_63fa1_row28_col5,#T_63fa1_row30_col32,#T_63fa1_row32_col14,#T_63fa1_row32_col44,#T_63fa1_row33_col2,#T_63fa1_row34_col0,#T_63fa1_row34_col28,#T_63fa1_row39_col29,#T_63fa1_row43_col20,#T_63fa1_row45_col9,#T_63fa1_row45_col21{
#             background-color:  #4400bb;
#             color:  #f1f1f1;
#         }#T_63fa1_row0_col11,#T_63fa1_row1_col14,#T_63fa1_row3_col45,#T_63fa1_row5_col16,#T_63fa1_row5_col45,#T_63fa1_row6_col13,#T_63fa1_row7_col32,#T_63fa1_row7_col45,#T_63fa1_row10_col1,#T_63fa1_row10_col13,#T_63fa1_row10_col35,#T_63fa1_row15_col21,#T_63fa1_row17_col10,#T_63fa1_row21_col7,#T_63fa1_row26_col15,#T_63fa1_row26_col49,#T_63fa1_row31_col28,#T_63fa1_row32_col22,#T_63fa1_row34_col1,#T_63fa1_row34_col31,#T_63fa1_row36_col0,#T_63fa1_row38_col5,#T_63fa1_row46_col32,#T_63fa1_row48_col10,#T_63fa1_row48_col29{
#             background-color:  #7e0081;
#             color:  #f1f1f1;
#         }#T_63fa1_row0_col12,#T_63fa1_row1_col45,#T_63fa1_row6_col44,#T_63fa1_row9_col21,#T_63fa1_row9_col30,#T_63fa1_row10_col40,#T_63fa1_row17_col2,#T_63fa1_row20_col16,#T_63fa1_row22_col18,#T_63fa1_row22_col32,#T_63fa1_row28_col22,#T_63fa1_row29_col16,#T_63fa1_row32_col35,#T_63fa1_row34_col44,#T_63fa1_row35_col2,#T_63fa1_row37_col36,#T_63fa1_row38_col12,#T_63fa1_row40_col2,#T_63fa1_row42_col4,#T_63fa1_row42_col9,#T_63fa1_row42_col44,#T_63fa1_row44_col18,#T_63fa1_row47_col9{
#             background-color:  #5600a9;
#             color:  #f1f1f1;
#         }#T_63fa1_row0_col15,#T_63fa1_row2_col19,#T_63fa1_row5_col2,#T_63fa1_row5_col12,#T_63fa1_row8_col14,#T_63fa1_row14_col38,#T_63fa1_row21_col0,#T_63fa1_row21_col18,#T_63fa1_row30_col0,#T_63fa1_row41_col14,#T_63fa1_row43_col3,#T_63fa1_row45_col46,#T_63fa1_row48_col37{
#             background-color:  #2600d9;
#             color:  #f1f1f1;
#         }#T_63fa1_row0_col16,#T_63fa1_row0_col22,#T_63fa1_row2_col18,#T_63fa1_row12_col42,#T_63fa1_row14_col7,#T_63fa1_row14_col16,#T_63fa1_row14_col29,#T_63fa1_row21_col29,#T_63fa1_row22_col33,#T_63f

# %% [markdown]
# #Correlation matrix for monthly data

# %%
gain_loss_monthly = gain_loss_monthly.sort_values(by=["gain_loss"])
gain_25_daily = gain_loss_monthly.head(25)
loss_25_daily = gain_loss_monthly.tail(25)

gain_25_daily_names = list(gain_25_daily["symbol"])
loss_25_daily_names = list(loss_25_daily["symbol"])

names = set(loss_25_daily_names+gain_25_daily_names)
samp = pd.DataFrame(columns=names,index=names)
for n1,n2 in combinations(names,2):
    df1 = daily_dfs[n1]
    df2 = daily_dfs[n2]
    samp.loc[n1,n2] = df1["Gain/Loss"].corr(df2["Gain/Loss"])
    samp.loc[n2,n1] = df2["Gain/Loss"].corr(df1["Gain/Loss"])
    samp.loc[n1,n1] = 1
    samp.loc[n2,n2] = 1
monthly_samp = samp.astype({name:"float" for name in names})
monthly_samp.style.background_gradient(cmap="brg")
# Out:
# <style  type="text/css" >
# #T_c122a_row0_col0,#T_c122a_row1_col1,#T_c122a_row2_col2,#T_c122a_row3_col3,#T_c122a_row4_col4,#T_c122a_row5_col5,#T_c122a_row6_col6,#T_c122a_row7_col7,#T_c122a_row8_col8,#T_c122a_row9_col9,#T_c122a_row10_col10,#T_c122a_row11_col11,#T_c122a_row12_col12,#T_c122a_row13_col13,#T_c122a_row14_col14,#T_c122a_row15_col15,#T_c122a_row16_col16,#T_c122a_row17_col17,#T_c122a_row18_col18,#T_c122a_row19_col19,#T_c122a_row20_col20,#T_c122a_row21_col21,#T_c122a_row22_col22,#T_c122a_row23_col23,#T_c122a_row24_col24,#T_c122a_row25_col25,#T_c122a_row26_col26,#T_c122a_row27_col27,#T_c122a_row28_col28,#T_c122a_row29_col29,#T_c122a_row30_col30,#T_c122a_row31_col31,#T_c122a_row32_col32,#T_c122a_row33_col33,#T_c122a_row34_col34,#T_c122a_row35_col35,#T_c122a_row36_col36,#T_c122a_row37_col37,#T_c122a_row38_col38,#T_c122a_row39_col39,#T_c122a_row40_col40,#T_c122a_row41_col41,#T_c122a_row42_col42,#T_c122a_row43_col43,#T_c122a_row44_col44,#T_c122a_row45_col45,#T_c122a_row46_col46,#T_c122a_row47_col47,#T_c122a_row48_col48,#T_c122a_row49_col49{
#             background-color:  #00ff00;
#             color:  #000000;
#         }#T_c122a_row0_col1,#T_c122a_row1_col29,#T_c122a_row3_col5,#T_c122a_row3_col25,#T_c122a_row4_col39,#T_c122a_row5_col40,#T_c122a_row7_col11,#T_c122a_row11_col7,#T_c122a_row14_col1,#T_c122a_row15_col1,#T_c122a_row15_col28,#T_c122a_row15_col33,#T_c122a_row17_col27,#T_c122a_row19_col22,#T_c122a_row19_col34,#T_c122a_row20_col0,#T_c122a_row21_col26,#T_c122a_row23_col20,#T_c122a_row27_col13,#T_c122a_row27_col26,#T_c122a_row27_col49,#T_c122a_row29_col22,#T_c122a_row30_col39,#T_c122a_row32_col9,#T_c122a_row32_col47,#T_c122a_row33_col12,#T_c122a_row34_col1,#T_c122a_row34_col19,#T_c122a_row42_col5,#T_c122a_row44_col7,#T_c122a_row44_col39,#T_c122a_row45_col5,#T_c122a_row46_col12{
#             background-color:  #b60049;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col2,#T_c122a_row0_col24,#T_c122a_row11_col40,#T_c122a_row15_col39,#T_c122a_row17_col12,#T_c122a_row24_col12,#T_c122a_row27_col11,#T_c122a_row32_col2,#T_c122a_row39_col19,#T_c122a_row39_col42,#T_c122a_row41_col12,#T_c122a_row43_col14,#T_c122a_row48_col2{
#             background-color:  #62009d;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col3,#T_c122a_row0_col9,#T_c122a_row1_col17,#T_c122a_row3_col32,#T_c122a_row4_col20,#T_c122a_row5_col18,#T_c122a_row5_col32,#T_c122a_row9_col12,#T_c122a_row12_col3,#T_c122a_row12_col26,#T_c122a_row12_col44,#T_c122a_row17_col15,#T_c122a_row19_col46,#T_c122a_row24_col7,#T_c122a_row24_col29,#T_c122a_row25_col15,#T_c122a_row26_col18,#T_c122a_row26_col37,#T_c122a_row32_col26,#T_c122a_row32_col27,#T_c122a_row33_col49,#T_c122a_row36_col34,#T_c122a_row41_col28,#T_c122a_row41_col33,#T_c122a_row43_col15,#T_c122a_row43_col28,#T_c122a_row49_col23{
#             background-color:  #e2001d;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col4,#T_c122a_row7_col33,#T_c122a_row8_col1,#T_c122a_row15_col37,#T_c122a_row25_col7,#T_c122a_row25_col17,#T_c122a_row28_col10,#T_c122a_row32_col1,#T_c122a_row33_col47,#T_c122a_row34_col32,#T_c122a_row35_col13,#T_c122a_row37_col26,#T_c122a_row38_col10,#T_c122a_row38_col48,#T_c122a_row41_col42,#T_c122a_row43_col31,#T_c122a_row44_col11,#T_c122a_row44_col38,#T_c122a_row48_col22{
#             background-color:  #ee0011;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col5,#T_c122a_row2_col23,#T_c122a_row2_col34,#T_c122a_row5_col20,#T_c122a_row7_col2,#T_c122a_row12_col17,#T_c122a_row14_col5,#T_c122a_row21_col18,#T_c122a_row21_col25,#T_c122a_row21_col35,#T_c122a_row23_col0,#T_c122a_row25_col38,#T_c122a_row31_col38,#T_c122a_row35_col44,#T_c122a_row39_col23,#T_c122a_row41_col48,#T_c122a_row43_col39,#T_c122a_row44_col27,#T_c122a_row44_col35{
#             background-color:  #70008f;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col6,#T_c122a_row5_col16,#T_c122a_row6_col20,#T_c122a_row6_col37,#T_c122a_row11_col6,#T_c122a_row29_col6,#T_c122a_row36_col16{
#             background-color:  #1200ed;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col7,#T_c122a_row0_col8,#T_c122a_row3_col15,#T_c122a_row3_col31,#T_c122a_row9_col45,#T_c122a_row10_col5,#T_c122a_row10_col24,#T_c122a_row12_col20,#T_c122a_row12_col49,#T_c122a_row17_col9,#T_c122a_row17_col20,#T_c122a_row24_col28,#T_c122a_row27_col30,#T_c122a_row30_col21,#T_c122a_row32_col44,#T_c122a_row33_col2,#T_c122a_row34_col9,#T_c122a_row34_col40,#T_c122a_row38_col32,#T_c122a_row40_col27,#T_c122a_row42_col4,#T_c122a_row43_col40,#T_c122a_row47_col49,#T_c122a_row49_col15,#T_c122a_row49_col38{
#             background-color:  #9a0065;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col10,#T_c122a_row5_col24,#T_c122a_row9_col34,#T_c122a_row10_col23,#T_c122a_row13_col45,#T_c122a_row15_col3,#T_c122a_row21_col22,#T_c122a_row22_col40,#T_c122a_row24_col26,#T_c122a_row26_col21,#T_c122a_row27_col42,#T_c122a_row30_col19,#T_c122a_row30_col25,#T_c122a_row30_col42,#T_c122a_row31_col34,#T_c122a_row38_col37,#T_c122a_row39_col33,#T_c122a_row45_col9{
#             background-color:  #a60059;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col11,#T_c122a_row4_col32,#T_c122a_row5_col25,#T_c122a_row9_col18,#T_c122a_row19_col33,#T_c122a_row20_col44,#T_c122a_row22_col8,#T_c122a_row25_col28,#T_c122a_row26_col39,#T_c122a_row28_col12,#T_c122a_row29_col20,#T_c122a_row40_col18,#T_c122a_row40_col23,#T_c122a_row43_col34,#T_c122a_row45_col37,#T_c122a_row45_col41,#T_c122a_row49_col29{
#             background-color:  #c80037;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col12,#T_c122a_row0_col18,#T_c122a_row0_col37,#T_c122a_row0_col43,#T_c122a_row2_col29,#T_c122a_row2_col44,#T_c122a_row4_col24,#T_c122a_row4_col45,#T_c122a_row5_col9,#T_c122a_row5_col10,#T_c122a_row11_col5,#T_c122a_row12_col0,#T_c122a_row14_col12,#T_c122a_row26_col45,#T_c122a_row28_col2,#T_c122a_row28_col24,#T_c122a_row34_col24,#T_c122a_row34_col47,#T_c122a_row39_col36,#T_c122a_row43_col0,#T_c122a_row43_col38,#T_c122a_row43_col47,#T_c122a_row44_col8,#T_c122a_row48_col49,#T_c122a_row49_col2{
#             background-color:  #8a0075;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col13,#T_c122a_row0_col33,#T_c122a_row1_col37,#T_c122a_row3_col7,#T_c122a_row4_col47,#T_c122a_row8_col7,#T_c122a_row13_col10,#T_c122a_row13_col32,#T_c122a_row17_col25,#T_c122a_row27_col8,#T_c122a_row28_col36,#T_c122a_row30_col1,#T_c122a_row30_col11,#T_c122a_row32_col34,#T_c122a_row33_col32,#T_c122a_row33_col41,#T_c122a_row33_col43,#T_c122a_row42_col23,#T_c122a_row49_col18{
#             background-color:  #f4000b;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col14,#T_c122a_row0_col31,#T_c122a_row0_col35,#T_c122a_row2_col38,#T_c122a_row10_col40,#T_c122a_row12_col5,#T_c122a_row14_col8,#T_c122a_row24_col38,#T_c122a_row32_col12,#T_c122a_row39_col35,#T_c122a_row40_col38,#T_c122a_row44_col29,#T_c122a_row44_col45{
#             background-color:  #74008b;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col15,#T_c122a_row17_col39,#T_c122a_row23_col2,#T_c122a_row27_col0,#T_c122a_row31_col12,#T_c122a_row39_col15,#T_c122a_row39_col45{
#             background-color:  #5600a9;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col16,#T_c122a_row21_col31,#T_c122a_row21_col45,#T_c122a_row27_col16{
#             background-color:  #4000bf;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col17,#T_c122a_row2_col47,#T_c122a_row4_col2,#T_c122a_row5_col11,#T_c122a_row7_col12,#T_c122a_row11_col31,#T_c122a_row14_col18,#T_c122a_row14_col34,#T_c122a_row14_col41,#T_c122a_row18_col14,#T_c122a_row20_col40,#T_c122a_row21_col7,#T_c122a_row22_col27,#T_c122a_row23_col47,#T_c122a_row25_col45,#T_c122a_row29_col47,#T_c122a_row39_col7,#T_c122a_row39_col8,#T_c122a_row42_col45,#T_c122a_row42_col47,#T_c122a_row47_col21,#T_c122a_row47_col23,#T_c122a_row48_col18{
#             background-color:  #82007d;
#             color:  #f1f1f1;
#         }#T_c122a_row0_col19,#T_c122a_row0_col42,#T_c122a_row2_col5,#T_c122a_row5_col48,#T_c122a_row12_col27,#T_c122a_row14_col0,#T_c122a_row14_col36,#T_c122a_row14_c

# %% [markdown]
# # 4.	For each company in top 25 and bottom 25, identify their GICS sectors from https://en.wikipedia.org/wiki/List_of_S%26P_500_companies and draw a bar graph depicting number of top 25 and bottom 25 belongs to that sector.  Do the same thing for weekly and monthly data.

# %%
#here we take the top and bottom 25 values to plot the bar graph.
top_25 = dict(gain_loss_daily["GICS"].head(25).value_counts())
bottom_25 = dict(gain_loss_daily["GICS"].tail(25).value_counts())
labels = set(list(top_25.keys()) + list(bottom_25.keys()))


for lab in labels:
    if lab in top_25:
        pass
    else:
        top_25[lab] = 0
    if lab in bottom_25:
        pass
    else:
        bottom_25[lab] = 0
#here we use plt library to draw the bar graph. by giving appropriate colors.
w = 0.2
ind = np.arange(len(labels))
ind2 = [i+w for i in ind]
plt.bar(ind,top_25.values(),w,color="r",label="top")
plt.bar(ind2,bottom_25.values(),w,color="b",label="bottom")
#for x- axis we give gisc sectors
plt.xlabel("gisc")
#for y - axis we give frequency.
plt.ylabel("frequency")
plt.xticks(ind+w/2,labels,rotation=90)
plt.title("daily")
plt.legend()

# %%
#here we take the top and bottom 25 values to plot the bar graph.
top_25 = dict(gain_loss_weekly["GICS"].head(25).value_counts())
bottom_25 = dict(gain_loss_weekly["GICS"].tail(25).value_counts())
labels = set(list(top_25.keys()) + list(bottom_25.keys()))


for lab in labels:
    if lab in top_25:
        pass
    else:
        top_25[lab] = 0
    if lab in bottom_25:
        pass
    else:
        bottom_25[lab] = 0
#here we use plt library to draw the bar graph. by giving appropriate colors.
w = 0.2
ind = np.arange(len(labels))
ind2 = [i+w for i in ind]
plt.bar(ind,top_25.values(),w,color="r",label="top")
plt.bar(ind2,bottom_25.values(),w,color="b",label="bottom")
#for x- axis we give gisc sectors
plt.xlabel("gisc")
#for y - axis we give frequency.
plt.ylabel("frequency")
plt.xticks(ind+w/2,labels,rotation=90)
plt.title("weekly")
plt.legend()

# %%
#here we take the top and bottom 25 values to plot the bar graph.
top_25 = dict(gain_loss_monthly["GICS"].head(25).value_counts())
bottom_25 = dict(gain_loss_monthly["GICS"].tail(25).value_counts())
labels = set(list(top_25.keys()) + list(bottom_25.keys()))


for lab in labels:
    if lab in top_25:
        pass
    else:
        top_25[lab] = 0
    if lab in bottom_25:
        pass
    else:
        bottom_25[lab] = 0
#here we use plt library to draw the bar graph. by giving appropriate colors.
w = 0.2
ind = np.arange(len(labels))
ind2 = [i+w for i in ind]
plt.bar(ind,top_25.values(),w,color="r",label="top")
plt.bar(ind2,bottom_25.values(),w,color="b",label="bottom")
#for x- axis we give gisc sectors
plt.xlabel("gisc")
#for y - axis we give frequency.
plt.ylabel("frequency")
plt.xticks(ind+w/2,labels,rotation=90)
plt.title("monthly")
plt.legend()

# %% [markdown]
# # 5.	For the top 2 companies, find the maximum negatively correlated companies in the remaining 48 companies from the correlation matrix.  Using Tornado templates, draw sparkline plots of the 4 companies of their daily gains or losses in the same chart. Do the same thing for weekly and monthly gains or losses. Do the same thing for bottom 2 companies. Convert these files into PDF without using a browser.

# %%
import base64

#for the purpose of building a spark line graph, we have to write this spark line method.
#parameters passed are data we pass about the 2 and 48 compnaies.

def spark_line(data, figsize=(4, 0.25), **kwags):
    """
    This method will Returns a HTML image tag containing a base64 encoded sparkline style plot
    """
    data = list(data)

    fig, ax = plt.subplots(1, 1, figsize=figsize, **kwags)
    ax.plot(data)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_xticks([])
    ax.set_yticks([])

    plt.plot(len(data) - 1, data[len(data) - 1], 'r.')

    ax.fill_between(range(len(data)), data, len(data)*[min(data)], alpha=0.1)
    
    #IO.bytes() will convert the web text to bytes and then embeds as an spark line image.
    img = io.BytesIO()
    plt.savefig(img, transparent=True, bbox_inches='tight')
    img.seek(0)
    plt.close()

    return base64.b64encode(img.read()).decode("UTF-8")

# %%
#Finding the negatively correlated companies for the top 2 companies - DAILY
top_four = list()
top_2 = gain_loss_daily.head(2)

#checking for the symbols and sorting values for each symbol.
for sym in top_2["symbol"]:
    tsym = daily_samp[sym].sort_values().index[0]
    top_four.append(sym)
    top_four.append(tsym)
    
#in this we use dropna() method to avoid the NA/NaN values in data.
all_values = list()
for num in top_four:
    val = list(daily_dfs[num]["Gain/Loss"].dropna().values)
    all_values.append(val)
    
#It opens the sparline for comparision.
with open("spark1.html", "a") as file:
        file.write('<div>Daily top</div>')
        for value in all_values:
            file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

#Doing the same above process in the bottom 2 companies.
bottom_four = list()
bottom_2 = gain_loss_daily.tail(2)
for sym in bottom_2["symbol"]:
    tsym = daily_samp[sym].sort_values().index[0]
    bottom_four.append(sym)
    bottom_four.append(tsym)
all_values = list()

for num in bottom_four:
    val = list(daily_dfs[num]["Gain/Loss"].dropna().values)
    all_values.append(val)
    
with open("spark1.html", "a") as file:
        file.write('<div>Daily bottom</div>')
        for value in all_values:
            file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

# %%
#Finding the negatively correlated companies for the top 2 companies - weekly
top_four = list()
top_2 = gain_loss_weekly.head(2)

#checking for the symbols and sorting values for each symbol.
for sym in top_2["symbol"]:
    tsym = weekly_samp[sym].sort_values().index[0]
    top_four.append(sym)
    top_four.append(tsym)
    
#in this we use dropna() method to avoid the NA/NaN values in data.
all_values = list()
for num in top_four:
    val = list(weekly_dfs[num]["Gain/Loss"].dropna().values)
    all_values.append(val)
    
#It opens the sparline for comparision.
with open("spark1.html", "a") as file:
        file.write('<div>Weekly top</div>')
        for value in all_values:
            file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

#Doing the same above process in the bottom 2 companies.
bottom_four = list()
bottom_2 = gain_loss_weekly.tail(2)
for sym in bottom_2["symbol"]:
    tsym = weekly_samp[sym].sort_values().index[0]
    bottom_four.append(sym)
    bottom_four.append(tsym)
all_values = list()

for num in bottom_four:
    val = list(weekly_dfs[num]["Gain/Loss"].dropna().values)
    all_values.append(val)
    
with open("spark1.html", "a") as file:
        file.write('<div>Weekly bottom</div>')
        for value in all_values:
            file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

# %%
#Finding the negatively correlated companies for the top 2 companies - monthly
top_four = list()
top_2 = gain_loss_monthly.head(2)

#checking for the symbols and sorting values for each symbol.
for sym in top_2["symbol"]:
    tsym = monthly_samp[sym].sort_values().index[0]
    top_four.append(sym)
    top_four.append(tsym)
    
#in this we use dropna() method to avoid the NA/NaN values in data.
all_values = list()
for num in top_four:
    val = list(monthly_dfs[num]["Gain/Loss"].dropna().values)
    all_values.append(val)
    
#It opens the sparline for comparision.
with open("spark1.html", "a") as file:
        file.write('<div>Monthly top</div>')
        for value in all_values:
            file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

#Doing the same above process in the bottom 2 companies.
bottom_four = list()
bottom_2 = gain_loss_monthly.tail(2)
for sym in bottom_2["symbol"]:
    tsym = monthly_samp[sym].sort_values().index[0]
    bottom_four.append(sym)
    bottom_four.append(tsym)
all_values = list()

for num in bottom_four:
    val = list(monthly_dfs[num]["Gain/Loss"].dropna().values)
    all_values.append(val)
    
with open("spark1.html", "a") as file:
        file.write('<div>Monthly bottom</div>')
        for value in all_values:
            file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

# %%
pip install pdfcrowd
# Out:
# Requirement already satisfied: pdfcrowd in c:\users\jayasimha\anaconda3\envs\notebook\lib\site-packages (5.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfcrowd

client = pdfcrowd.HtmlToPdfClient('demo', 'ce544b6ea52a5621fb9d55f8b542d14d')
client.convertFileToFile('spark1.html', 'spark1.pdf')
